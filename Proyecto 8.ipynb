# %% [markdown]
# **Comentario del Revisor**
#
# Hola!
#
# Soy Juan Manuel Romero, pero siéntete libre de llamarme Juanma. Soy code reviewer en Tripleten y hoy estaré revisando tu entrega.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Solo un aviso rápido: cuando estés revisando el proyecto, por favor deja mis comentarios originales tal como están. De esta manera, podemos seguir fácilmente el progreso y asegurarnos de que no se nos pase nada por alto. Y, si realizas algún cambio basado en mis comentarios, sería genial si pudieras resaltar esas actualizaciones para que se destaquen.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como estas:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo se ha hecho correctamente.
#
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
#
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Requiere corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con los comentarios en rojo.
#
# </div>
#
# Puedes responderme usando esto:
#
# <div class="alert alert-block alert-info"> <b>Respuesta del estudiante.</b> <a class="tocSkip"></a> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Felicidades Fercho! Tu trabajo es excelente.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Te recomiendo usar celdas de tipo **Markdown** para organizar mejor tu trabajo. Puedes agregar **títulos**, separar secciones y explicar tu código de manera clara. Esto no solo mejora la legibilidad, sino que también te ayuda a entender y explicar mejor tu proceso. 📚✍️
#
# </div>
#
# Has completado todos los items necesarios para aprobar la entrega.
#
# Sigue así!
#
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al separar la importación de bibliotecas del resto del código! Esto mejora la estructura y claridad de tu código.
#
# </div>

# %%
result_01 = pd.read_csv('/datasets/project_sql_result_01.csv')

# %%
result_04 = pd.read_csv('/datasets/project_sql_result_04.csv')

# %%
result_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
print(result_01.head())
# Out:
#                       company_name  trips_amount
# 0                        Flash Cab         19558
# 1        Taxi Affiliation Services         11422
# 2                Medallion Leasing         10367
# 3                       Yellow Cab          9888
# 4  Taxi Affiliation Service Yellow          9299

# %% [markdown]
# ##### Los datos de este dataframe son correctos y no tienen datos faltantes

# %%
result_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dropoff_location_name  94 non-null     object
#  1   average_trips          94 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.6+ KB

# %%
print(result_04.head())
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo estudiando los datasets! Esto es fundamental para entender los datos y planificar el análisis.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Recuerda dejar comentarios sobre tus análisis de los mismos.
#
# </div>
#
# </div>

# %% [markdown]
# ##### Los datos de este dataframe son correctos y no tienen datos faltantes

# %%
top_10_barrios = result_04.head(10)

# %%
print('Los 10 principales barrios por finalizacion de viajes')
print()
print(top_10_barrios)
# Out:
# Los 10 principales barrios por finalizacion de viajes
#
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000
# 5             Lake View    2420.966667
# 6            Grant Park    2068.533333
# 7         Museum Campus    1510.000000
# 8            Gold Coast    1364.233333
# 9    Sheffield & DePaul    1259.766667

# %%
top_10_compañias = result_01.head(10)
print('Las 10 principales comapañias con numero de viajes')
print()
print(top_10_compañias)
# Out:
# Las 10 principales comapañias con numero de viajes
#
#                         company_name  trips_amount
# 0                          Flash Cab         19558
# 1          Taxi Affiliation Services         11422
# 2                  Medallion Leasing         10367
# 3                         Yellow Cab          9888
# 4    Taxi Affiliation Service Yellow          9299
# 5          Chicago Carriage Cab Corp          9181
# 6                       City Service          8448
# 7                           Sun Taxi          7701
# 8          Star North Management LLC          7455
# 9  Blue Ribbon Taxi Association Inc.          5953

# %%
top_10_compañias.plot(title='Numero de viajes por compañia(Top 10 compañias con mas biajes)', kind='bar', x='company_name', y='trips_amount', xlabel='Compañias', ylabel='Numero de viajes', color=['Red','Blue','Yellow','Green','Orange','Purple','Pink','Black','Brown','Grey'])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto! El gráfico es correcto y refleja adecuadamente el resultado esperado.
#
# </div>

# %%
top_10_barrios.plot(title='Numero de viajes finalizados por barrio (Barrios con mas recorridos)', kind='bar', x='dropoff_location_name', y='average_trips', xlabel='Barrios', ylabel='Promedio de viajes', color=['Red','Blue','Yellow','Green','Orange','Purple','Pink','Black','Brown','Grey'])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# El gráfico de barras con el top 10 por barrios es excelente y los resultados son los esperados.
#
# </div>

# %% [markdown]
# ##### Es obvio que la empresa Flash Cab tiene muchos mas viajes que las otras compañias las demas compañias tienen un promedio similar entre el numero de viajes.
# ##### En los barrios con mas viajes Loop es la que tiene mas viajes las 3 siguientes empresas tienen una disminucion de viajes considerable y las siguientes tienen en una caida significativa.
# ##### Podria recomendar hacer un analisis mas completo para saber que compañias hacen vaijes en que barrios y reisar cuales necesitan mas intensivos para que suban su numero de viajes.

# %%
result_05 = pd.read_csv('/datasets/project_sql_result_07.csv')

# %% [markdown]
# ### Hipotesis
# ##### "La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos".

# %% [markdown]
# ##### Hipotesis Nula "La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos".

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo formulando la hipótesis! Es fundamental que sea claro lo que se busca analizar.
#
# </div>

# %% [markdown]
# ##### Hipotesis alternativa  La duración promedio de viajes Loop → O'Hare SÍ cambia los sábados lluviosos

# %%
result_05.info()
print(result_05.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   object
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 25.2+ KB
#               start_ts weather_conditions  duration_seconds
# 0  2017-11-25 16:00:00               Good            2410.0
# 1  2017-11-25 14:00:00               Good            1920.0
# 2  2017-11-25 12:00:00               Good            1543.0
# 3  2017-11-04 10:00:00               Good            2512.0
# 4  2017-11-11 07:00:00               Good            1440.0

# %%
print("Condiciones climáticas únicas:")
print(result_05['weather_conditions'].unique())
print("\nConteo de cada condición:")
print(result_05['weather_conditions'].value_counts())
# Out:
# Condiciones climáticas únicas:
# ['Good' 'Bad']
#
# Conteo de cada condición:
# Good    888
# Bad     180
# Name: weather_conditions, dtype: int64

# %%
result_05['start_ts'] = pd.to_datetime(result_05['start_ts'])
result_05['day_of_week'] = result_05['start_ts'].dt.dayofweek
print("Días de la semana únicos:", result_05['day_of_week'].unique())
# Out:
# Días de la semana únicos: [5]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Perfecto! Comprobar las varianzas te asegura un uso correcto de las pruebas estadísticas.
#
# </div>

# %%
from scipy.stats import levene, ttest_ind

good_weather = result_05[result_05['weather_conditions'] == 'Good']['duration_seconds']
bad_weather = result_05[result_05['weather_conditions'] == 'Bad']['duration_seconds']

stat, p_value= levene(good_weather, bad_weather)

print(f"Estadístico de Levene: {stat}")
print(f"Valor p: {p_value}")

alpha = 0.05
results = ttest_ind(good_weather, bad_weather, equal_var=False)

print('valor_p:', results.pvalue)
if (results.pvalue < alpha): 
    print("Rechazamos la hipótesis nula")
else:
    print("No podemos rechazar la hipótesis nula")
# Out:
# Estadístico de Levene: 0.38853489683656073
# Valor p: 0.5332038671974493
# valor_p: 6.738994326108734e-12
# Rechazamos la hipótesis nula

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Interpretaste correctamente el valor p y sacaste conclusiones estadísticas válidas. Debemos rechazar efectivamente la hipótesis nula.
#
# </div>

# %% [markdown]
# ##### Los datos demuestran que nuestra hipotesis debe ser rechaza ya que si hay cambios los dias en los que el clima es malo
